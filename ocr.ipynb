# %%
from paddlex import create_pipeline

pipeline = create_pipeline(pipeline="OCR")

output = pipeline.predict("/home/jiajun/公共/jiajun/History_backend/images/15建党以来重要文献选编 第十五册__4.png")
for res in output:
    res.print()
# Out:
# Using official model (PP-OCRv4_mobile_det), the model files will be be automatically downloaded and saved in /home/jiajun/.paddlex/official_models.
# Using official model (PP-OCRv4_mobile_rec), the model files will be be automatically downloaded and saved in /home/jiajun/.paddlex/official_models.
# {'input_path': '/home/jiajun/公共/jiajun/History_backend/images/15建党以来重要文献选编 第十五册__4.png', 'dt_polys': [array([[ 722,  378],
#        [2597,  378],
#        [2597,  467],
#        [ 722,  467]], dtype=int16), array([[ 410,  583],
#        [1261,  583],
#        [1261,  688],
#        [ 410,  688]], dtype=int16), array([[2753,  599],
#        [2915,  599],
#        [2915,  677],
#        [2753,  677]], dtype=int16), array([[ 609,  730],
#        [1498,  730],
#        [1498,  819],
#        [ 609,  819]], dtype=int16), array([[ 404,  851],
#        [2182,  851],
#        [2182,  956],
#        [ 404,  956]], dtype=int16), array([[ 506,  992],
#        [1719,  992],
#        [1719, 1097],
# ...
